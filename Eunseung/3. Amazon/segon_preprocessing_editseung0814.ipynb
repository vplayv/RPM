# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('190809_163536_Honor 9N.csv')
df2 = pd.read_csv('190809_172154_Samsung Galaxy A8+.csv')
df3 = pd.read_csv('190809_182220_OnePlus 6T.csv')
df4 = pd.read_csv('190809_182351_LG W30.csv')
df5 = pd.read_csv('190809_190132_Vivo Y17.csv')
df6 = pd.read_csv('190809_195539_Honor 8X.csv')
df7 = pd.read_csv('190809_205712_Vivo Y91.csv')
df8 = pd.read_csv('190809_214831_Samsung Galaxy A10.csv')
df9 = pd.read_csv('190809_221043_Vivo Y91i.csv')
df10 = pd.read_csv('190809_234135_Redmi 6.csv')
df11 = pd.read_csv('190810_000639_OnePlus 7.csv')
df12 = pd.read_csv('190810_002209_Mi Redmi 6A.csv')
df13 = pd.read_csv('190810_010814_Vivo V15 Pro.csv')
df14 = pd.read_csv('190810_013445_Nokia 6.1 Plus.csv')
df15 = pd.read_csv('190810_020843_Redmi 6 Pro.csv')
df16 = pd.read_csv('190810_021731_Realme U1.csv')
df17 = pd.read_csv('190810_022617_Samsung Galaxy M40.csv')
df18 = pd.read_csv('190810_102412_OPPO K3.csv')
df19 = pd.read_csv('190810_030655_Redmi Y2.csv')
df20 = pd.read_csv('190810_031346_OPPO A7.csv')
df21 = pd.read_csv('190810_033227_OnePlus 7 Pro.csv')
df22 = pd.read_csv('190810_033600_OPPO F11.csv')
df23 = pd.read_csv('190810_033646_Realme 3.csv')
df24 = pd.read_csv('190810_033855_Apple iPhone XR.csv')
df25 = pd.read_csv('190810_033951_Vivo Y15.csv')
df26 = pd.read_csv('190810_035907_Redmi Note 5 Pro.csv')
df27 = pd.read_csv('190810_040357_Xiaomi Mi A2.csv')
df28 = pd.read_csv('190810_041238_Samsung Galaxy A50.csv')
df29 = pd.read_csv('190810_042146_OPPO F11 Pro.csv')
df30 = pd.read_csv('190810_051832_Samsung Galaxy M20.csv')
df31 = pd.read_csv('190810_005556_Samsung Galaxy M30.csv')
df32 = pd.read_csv('190810_062713_Realme 3 Pro.csv')
df33 = pd.read_csv('190810_091254_Redmi 7.csv')
df34 = pd.read_csv('190810_092117_Vivo V15.csv')
df35 = pd.read_csv('190810_092828_Honor 8C.csv')
df36 = pd.read_csv('190810_094048_Redmi Y3.csv')
df37 = pd.read_csv('190810_102255_Samsung Galaxy M10.csv')

# %%
df1['Name'] = 'Huawei Honor 9N'
df2['Name'] = 'Samsung Galaxy A8+'
df3['Name'] = 'OPPO OnePlus 6T'
df4['Name'] = 'Others LG W30'
df5['Name'] = 'Vivo Y17'
df6['Name'] = 'Huawei Honor 8X'
df7['Name'] = 'Vivo Y91'
df8['Name'] = 'Samsung Galaxy A10'
df9['Name'] = 'Vivo Y91i'
df10['Name'] = 'Xiaomi Redmi 6'
df11['Name'] = 'OPPO OnePlus 7'
df12['Name'] = 'Xiaomi Redmi 6A'
df13['Name'] = 'Vivo V15 Pro'
df14['Name'] = 'Others Nokia 6.1 Plus'
df15['Name'] = 'Xiaomi Redmi 6 Pro'
df16['Name'] = 'Realme Realme U1'
df17['Name'] = 'Samsung Galaxy M40'
df18['Name'] = 'OPPO K3'
df19['Name'] = 'Xiaomi Redmi Y2'
df20['Name'] = 'OPPO A7'
df21['Name'] = 'OPPO OnePlus 7 Pro'
df22['Name'] = 'OPPO F11'
df23['Name'] = 'Realme Realme 3'
df24['Name'] = 'Others Apple iPhone XR'
df25['Name'] = 'Vivo Y15'
df26['Name'] = 'Xiaomi Redmi Note 5 Pro'
df27['Name'] = 'Xiaomi Mi A2'
df28['Name'] = 'Samsung Galaxy A50'
df29['Name'] = 'OPPO F11 Pro'
df30['Name'] = 'Samsung Galaxy M20'
df31['Name'] = 'Samsung Galaxy M30'
df32['Name'] = 'Realme Realme 3 Pro'
df33['Name'] = 'Xiaomi Redmi 7'
df34['Name'] = 'Vivo V15'
df35['Name'] = 'Huawei Honor 8C'
df36['Name'] = 'Xiaomi Redmi Y3'
df37['Name'] = 'Samsung Galaxy M10'

# %%
df_merge = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, 
           df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, 
           df21, df22, df23, df24, df25, df26, df27, df28, df29, df30, 
           df31, df32, df33, df34, df35,df36, df37], ignore_index = True)
df_merge.head()
# Out:
#    Unnamed: 0                             Title  Point             Date  \
# 0           0    No active dual volte standby\n    1.0  3 February 2019
# 1           1                Waste of money..\n    1.0      26 May 2019
# 2           2                            poor\n    1.0  22 October 2018
# 3           3      Worst phone do go for this\n    1.0      20 May 2019
# 4           4  Hanging p4oblen after two days\n    1.0     27 June 2019
#
#                      Feature             Name
# 0   Colour: BlueStyle: 128GB  Huawei Honor 9N
# 1   Colour: BlackStyle: 64GB  Huawei Honor 9N
# 2   Colour: BlueStyle: 128GB  Huawei Honor 9N
# 3  Colour: BlackStyle: 128GB  Huawei Honor 9N
# 4    Colour: BlueStyle: 64GB  Huawei Honor 9N

# %%
type(df_merge['Name'])
df_array = np.array(df_merge['Name'].tolist())
df_array = [line.split()[0] for line in df_array]
# print(df_array)
df_merge['Vendor'] = df_array
df_merge.head()
# Out:
#    Unnamed: 0                             Title  Point             Date  \
# 0           0    No active dual volte standby\n    1.0  3 February 2019
# 1           1                Waste of money..\n    1.0      26 May 2019
# 2           2                            poor\n    1.0  22 October 2018
# 3           3      Worst phone do go for this\n    1.0      20 May 2019
# 4           4  Hanging p4oblen after two days\n    1.0     27 June 2019
#
#                      Feature             Name  Vendor
# 0   Colour: BlueStyle: 128GB  Huawei Honor 9N  Huawei
# 1   Colour: BlackStyle: 64GB  Huawei Honor 9N  Huawei
# 2   Colour: BlueStyle: 128GB  Huawei Honor 9N  Huawei
# 3  Colour: BlackStyle: 128GB  Huawei Honor 9N  Huawei
# 4    Colour: BlueStyle: 64GB  Huawei Honor 9N  Huawei

# %%
merge_count = df_merge['Vendor'].groupby(df_merge['Vendor']).count()
merge_count
# Out:
# Vendor
# Huawei     12620
# OPPO       27510
# Others      1420
# Realme     12200
# Samsung    55360
# Vivo        6010
# Xiaomi     80150
# Name: Vendor, dtype: int64

# %%
merge_bar = df_merge.groupby('Vendor')['Vendor'].count()
merge_bar.plot(kind = 'bar')

# %%
plt.rcParams['figure.figsize'] = [12, 8]
group_names = ['Huawei', 'OPPO', 'Realme', 'Samsung', 'Vivo', 'Xiaomi', 'Others']
group_size = [12620, 27510, 12200, 55360, 6010, 80150, 1420]
group_colors = ['gold', 'lightgray', 'orange', 'yellowgreen', 'lightskyblue', 'lightpink', 'gray']
group_explodes = (0, 0, 0, 0.1, 0, 0.1, 0.1)

# %%
plt.pie(group_size, explode = group_explodes, labels = group_names, colors = group_colors, 
       autopct = '%1.2f%%', shadow = True, startangle = 90)
plt.axis('equal')
plt.title('India Online Market Share', fontsize = 20)
plt.show()

# %%
from dateutil import parser
import datetime

# %%
import calendar
parser_date = []
for i in df_merge['Date'] :
    parser_date.append(parser.parse(i).strftime('%Y-%m-%d'))

# %%
df_merge['Date_new'] = parser_date
df_merge.head()
# Out:
#    Unnamed: 0                             Title  Point             Date  \
# 0           0    No active dual volte standby\n    1.0  3 February 2019
# 1           1                Waste of money..\n    1.0      26 May 2019
# 2           2                            poor\n    1.0  22 October 2018
# 3           3      Worst phone do go for this\n    1.0      20 May 2019
# 4           4  Hanging p4oblen after two days\n    1.0     27 June 2019
#
#                      Feature             Name  Vendor    Date_new
# 0   Colour: BlueStyle: 128GB  Huawei Honor 9N  Huawei  2019-02-03
# 1   Colour: BlackStyle: 64GB  Huawei Honor 9N  Huawei  2019-05-26
# 2   Colour: BlueStyle: 128GB  Huawei Honor 9N  Huawei  2018-10-22
# 3  Colour: BlackStyle: 128GB  Huawei Honor 9N  Huawei  2019-05-20
# 4    Colour: BlueStyle: 64GB  Huawei Honor 9N  Huawei  2019-06-27

# %%
df_merge.to_csv("df_merge_online.csv")

# %%
df_merge_ms = df_merge[['Vendor', 'Date_new']]
df_merge_ms.head()
# Out:
#    Vendor    Date_new
# 0  Huawei  2019-02-03
# 1  Huawei  2019-05-26
# 2  Huawei  2018-10-22
# 3  Huawei  2019-05-20
# 4  Huawei  2019-06-27

# %%
df_merge_ms = df_merge_ms.set_index(['Date_new'])

# %%
df_merge_ms.head()
# Out:
#             Vendor
# Date_new
# 2019-02-03  Huawei
# 2019-05-26  Huawei
# 2018-10-22  Huawei
# 2019-05-20  Huawei
# 2019-06-27  Huawei

# %%
from datetime import datetime
start = datetime.datetime(2019, 7, 28)
end = datetime.datetime(2019, 8, 3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-c3d369a7842a> in <module>
#       1 from datetime import datetime
# ----> 2 start = datetime.datetime(2019, 7, 28)
#       3 end = datetime.datetime(2019, 8, 3)
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
df_merge
# Out:
#         Unnamed: 0                                              Title  Point  \
# 0                0                     No active dual volte standby\n    1.0
# 1                1                                 Waste of money..\n    1.0
# 2                2                                             poor\n    1.0
# 3                3                       Worst phone do go for this\n    1.0
# 4                4                   Hanging p4oblen after two days\n    1.0
# 5                5            VERY UPSETTING EXPERIENCE WITH AMAZON\n    1.0
# 6                6                                    Worst product\n    1.0
# 7                7                          Bad experience honor 9n\n    1.0
# 8                8                                   Waste of money\n    1.0
# 9                9                              Not worth for money\n    1.0
# 10              10                              NOT WORTH FOR MONEY\n    1.0
# ...

# %%
# parser_date = []
for i in df_merge['Date_new'] :
    parser_date.append(datetime.strptime(i, '%Y-%m-%d'))

# %%
df_merge
# Out:
#         Unnamed: 0                                              Title  Point  \
# 0                0                     No active dual volte standby\n    1.0
# 1                1                                 Waste of money..\n    1.0
# 2                2                                             poor\n    1.0
# 3                3                       Worst phone do go for this\n    1.0
# 4                4                   Hanging p4oblen after two days\n    1.0
# 5                5            VERY UPSETTING EXPERIENCE WITH AMAZON\n    1.0
# 6                6                                    Worst product\n    1.0
# 7                7                          Bad experience honor 9n\n    1.0
# 8                8                                   Waste of money\n    1.0
# 9                9                              Not worth for money\n    1.0
# 10              10                              NOT WORTH FOR MONEY\n    1.0
# ...

# %%
df_merge['Date_new'] = pd.to_datetime(df_merge.loc[:,'Date_new'])

# %%
df = df_merge[['Date_new', 'Vendor']]
df.head()
# Out:
#     Date_new  Vendor
# 0 2019-02-03  Huawei
# 1 2019-05-26  Huawei
# 2 2018-10-22  Huawei
# 3 2019-05-20  Huawei
# 4 2019-06-27  Huawei

# %%
df = df.set_index('Date_new')
df.head()
# Out:
#             Vendor
# Date_new
# 2019-02-03  Huawei
# 2019-05-26  Huawei
# 2018-10-22  Huawei
# 2019-05-20  Huawei
# 2019-06-27  Huawei

# %%
df = df.resample('W')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-eea756f8fa14> in <module>
# ----> 1 df = df.resample('W')
#
# ~\Anaconda3\lib\site-packages\pandas\core\resample.py in __getattr__(self, attr)
#      99             return self[attr]
#     100
# --> 101         return object.__getattribute__(self, attr)
#     102
#     103     def __iter__(self):
#
# AttributeError: 'DatetimeIndexResampler' object has no attribute 'resample'

# %%
# Out:
# pandas._libs.tslibs.timestamps.Timestamp
