# %%
import pandas as pd

# %%
review_rating = pd.read_csv('Non_Progressed_Flipkart_data.csv')

# %%
review_rating.head()
# Out:
#                                   Product_name  Quarter               Region  \
# 0  Alcatel 3V (Spectrum Gold, 32 GB)(3 GB RAM)  2019 3Q  == NOT AVAILABLE ==
# 1  Alcatel 3V (Spectrum Gold, 32 GB)(3 GB RAM)  2019 3Q       Baksa District
# 2  Alcatel 3V (Spectrum Gold, 32 GB)(3 GB RAM)  2019 3Q              Bharuch
# 3  Alcatel 3V (Spectrum Gold, 32 GB)(3 GB RAM)  2019 3Q           Bongaigaon
# 4  Alcatel 3V (Spectrum Gold, 32 GB)(3 GB RAM)  2019 3Q    Dehradun District
#
#    Current_price  Count   Latitude  Longitude  Vendor Price_category  \
# 0           5999      7  13.535496  82.297328  Others            Low
# 1           5999      1  26.656030  90.779303  Others            Low
# 2           5999      1  21.727747  72.933589  Others            Low
# 3           5999      1  26.489553  90.500879  Others            Low
# 4           5999      1  30.480682  77.382898  Others            Low
#
#    Unnamed: 9  73254
# 0         NaN    NaN
# 1         NaN    NaN
# ...
