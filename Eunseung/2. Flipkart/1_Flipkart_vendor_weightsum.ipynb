# %%
import pandas as pd

# %%
vendor_weigh = pd.read_csv('PRODUCTWISE_2019-08-27.csv')

# %%
vendor_weigh.head()
# Out:
#                                   Product_name  Week1  Week2  Week3  Week4  \
# 0  Alcatel 3V (Spectrum Blue, 32 GB)(3 GB RAM)      0      3      3      9
# 1  Alcatel 3V (Spectrum Gold, 32 GB)(3 GB RAM)      3      4      3      9
# 2              Apple iPhone 6s (Silver, 32 GB)     11     18     15     14
# 3          Apple iPhone 6s (Space Grey, 32 GB)      0     11     18     13
# 4      Apple iPhone 6s Plus (Rose Gold, 32 GB)      1      4      4      3
#
#    Week5  Weight_sum
# 0      8       19.60
# 1      4       20.35
# 2      4       56.70
# 3     15       49.70
# 4      4       14.15

# %%
# # week21 ~ 81 column 삭제 (필요한 칼럼만 살려두기!)
# vendor_weigh = vendor_weigh.drop(vendor_weigh.columns[1], axis='columns')
# vendor_weigh = vendor_weigh.drop(vendor_weigh.columns[5:], axis='columns')
# # vendor_weigh = vendor_weigh.drop(vendor_weigh.columns[22:83], axis='columns')
# vendor_weigh.head()

# %%
#칼럼명 바꾸기 
vendor_weigh.rename(columns={vendor_weigh.columns[0]:"Vendor"}, inplace = True)

# %%
#데이터 타입 문자열로 변경
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].astype(str)

# %%
# #결측값 제거
# vendor_weigh.dropna().head()

# %%
#띄어쓰기 별로 나누기
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].str.split(' ').str[0]

# %%
# Others로 변경 전, 제품 앞부분만 합계
vendor_weigh_real_vendor = vendor_weigh.groupby(['Vendor']).sum()
vendor_weigh_real_vendor
# Out:
#            Week1  Week2  Week3  Week4  Week5  Weight_sum
# Vendor
# Alcatel        3      7      6     18     12       39.95
# Apple         37     90     79     74     71      313.30
# Asus         778   1156   1078   1023    987     4505.55
# BLU            0      0      0      0      0        0.00
# Cloudfone      0      0      0      0      0        0.00
# Forme          0      0      0      0      0        0.00
# Gionee         0      0      0      0      0        0.00
# Gome           0      0      0      0      0        0.00
# Google         1     10      1      3      3       16.35
# HTC            0      0      0      0      0        0.00
# Honor        759   1326   1312   1546   1083     5380.00
# InFocus        0      0      0      0      0        0.00
# Infinix      425    531    566    571    595     2400.20
# Intex          0      0      0      0      0        0.00
# Itel           0      0      0      1      0        0.85
# ...

# %%
#진짜 벤더로 이름 변경 & 꼬리부분 others로 병합
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Redmi','Xiaomi')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Mi','Xiaomi')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('POCO','Xiaomi')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Honor','Huawei')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('OnePlus','OPPO')


vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Zen','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Nipda','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Itel','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('SSKY','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('STK','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Rio','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Tecno','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('BLU','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('T-Max','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Spice','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('LG','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Lava','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Intex','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('XOLO','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Asus','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Google','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Infinix','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Micromax','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Mobiistar','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Lenovo','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Nokia','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Moto','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Panasonic','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Nubia','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Alcatel','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Gionee','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Forme','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('KXD','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Karbonn','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Nextbit','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('TCL','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Winstar','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Meizu','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Apple','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('BSNL','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Coolpad','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Energy','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Ginger','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Good','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Icubex','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('InFocus','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Lemon','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Rage','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Voto','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Wham','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('obi','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Gome','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('IQ','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('HTC','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Motorola','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Nexian','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Ringing','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Rivo','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Sony','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Virat','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Yu','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('MHL','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Seatel','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Uinitel','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Cloudfone','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('Phonemax','Others')
vendor_weigh['Vendor'] = vendor_weigh['Vendor'].replace('iVooMi','Others')

# %%
#벤더 별로 가중치 합치기
vendor_weigh_2 = vendor_weigh.groupby(['Vendor']).sum()
vendor_weigh_2
# Out:
#          Week1  Week2  Week3  Week4  Week5  Weight_sum
# Vendor
# Huawei     759   1326   1312   1546   1083     5380.00
# OPPO        80    376    292    366    406     1335.90
# Others    1328   1897   1820   1794   1748     7691.45
# Realme    6528  13813  14404  15118  12549    55503.45
# Samsung    197    355    396    357    356     1478.90
# Vivo      1593   2582   2183   2666   2622    10374.30
# Xiaomi    5555   7877   7242   8159   6828    31953.50

# %%
# 칼럼명 변경
vendor_weigh_2.columns = ["Week34", "Week33", "Week32", "Week31","Week30", "Weight_sum"]

#칼럼명으로 오름차순 정렬

vendor_weigh_2 = vendor_weigh_2.sort_index(axis =1 , ascending = True)
vendor_weigh_2
# Out:
#          Week30  Week31  Week32  Week33  Week34  Weight_sum
# Vendor
# Huawei     1083    1546    1312    1326     759     5380.00
# OPPO        406     366     292     376      80     1335.90
# Others     1748    1794    1820    1897    1328     7691.45
# Realme    12549   15118   14404   13813    6528    55503.45
# Samsung     356     357     396     355     197     1478.90
# Vivo       2622    2666    2183    2582    1593    10374.30
# Xiaomi     6828    8159    7242    7877    5555    31953.50

# %%
# ####################################################
# #####주차별 가중치합 (기존의 Weight_sum과 달리, 2~4주차치만 뽑은 데이터!)


# vendor_weigh_2['Weight_sum'] = vendor_weigh_2['Week33'] + vendor_weigh_2['Week32'] + vendor_weigh_2['Week31'] + vendor_weigh_2['Week30']
# # + vendor_weigh_2['Week4']

# %%
#내림차순으로 정렬
vendor_weigh_2 = vendor_weigh_2.sort_values(["Weight_sum"], ascending=[False])

# %%
#Weight_sum탈락시키기
vendor_weigh_review_count = vendor_weigh_2.drop(vendor_weigh_2.columns[-1:], axis='columns')

# %%
# csv파일로 저장하기
data = pd.DataFrame(vendor_weigh_2)
data.to_csv('flipkart_vendor_weight_sum.csv')

# %%
#파이차트 라이브러리
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib import rc

# %matplotlib inline

# %%
#벤더 + weigh_sum만 불러오기
vendor_weigh_3 = vendor_weigh_2[['Weight_sum']]
vendor_weigh_3
# Out:
#          Weight_sum
# Vendor
# Realme     55503.45
# Xiaomi     31953.50
# Vivo       10374.30
# Others      7691.45
# Huawei      5380.00
# Samsung     1478.90
# OPPO        1335.90

# %%
#[ 삼성*블루 = #0A709A // 샤오미*연한레드 = #F44E54  // 리얼미*오렌지 = #FF9904/// 비보*연노  = #FDDB5E // 연한초록 = #76AD3B,  ,  노랑 = #FDDB5E, #BAF1A1 =연두
# [ 초록 = #76AD3B, skyblue

#파이차트 그리기
plt.pie(vendor_weigh_3,
        explode = (0 ,0 , 0 , 0,  0, 0.4 ,0),
        labels = ['Realme', 'Xiaomi', 'Vivo','Others', 'Huawei', 'Samsung', 'OPPO' ],
        colors = ['#FF9904', '#F44E54','#FDDB5E', '#BAF1A1', '#76AD3B','dodgerblue','green'], 
        startangle = 180,
        autopct = '%1.2f%%')

plt.rcParams.update({'font.size': 25})
plt.rcParams['figure.figsize'] = [20, 15]
plt.axis('equal', fontsize=18)
plt.title('Flipkart Review Share', fontsize = 40)       
plt.legend(fontsize=20, loc='upper left|')

plt.show()
# Out:
# C:\Users\LES\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\LES\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: MatplotlibDeprecationWarning: Unrecognized location 'upper left|'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   app.launch_new_instance()

# %%
#백분율 구하기 vendor_weigh_2
vendor_weigh_2_per = (vendor_weigh_2[0:20] / vendor_weigh_2[0:20].sum()) * 100
vendor_weigh_2_per
# Out:
#             Week30     Week31     Week32     Week33     Week34  Weight_sum
# Vendor
# Realme   49.034855  50.383257  52.095917  48.937150  40.698254   48.808187
# Xiaomi   26.680213  27.191228  26.192629  27.906894  34.632170   28.099017
# Vivo     10.245389   8.884890   7.895403   9.147594   9.931421    9.122870
# Others    6.830259   5.978804   6.582517   6.720754   8.279302    6.763647
# Huawei    4.231791   5.152303   4.745199   4.697796   4.731920    4.731022
# Samsung   1.391060   1.189762   1.432240   1.257706   1.228180    1.300503
# OPPO      1.586433   1.219756   1.056096   1.332105   0.498753    1.174753

# %%
# csv파일로 저장하기 (주별 리뷰 점유율 percentage)
data1 = pd.DataFrame(vendor_weigh_2_per)
data1.to_csv('weekly_flipkart_vendor_weight_sum_percetage#.csv')

# %%
#행과 열을 바꾸기
vendor_weigh_2_per = np.transpose(vendor_weigh_2_per)
vendor_weigh_2_per.head()
# Out:
# Vendor     Realme     Xiaomi       Vivo    Others    Huawei   Samsung  \
# Week30  49.034855  26.680213  10.245389  6.830259  4.231791  1.391060
# Week31  50.383257  27.191228   8.884890  5.978804  5.152303  1.189762
# Week32  52.095917  26.192629   7.895403  6.582517  4.745199  1.432240
# Week33  48.937150  27.906894   9.147594  6.720754  4.697796  1.257706
# Week34  40.698254  34.632170   9.931421  8.279302  4.731920  1.228180
#
# Vendor      OPPO
# Week30  1.586433
# Week31  1.219756
# Week32  1.056096
# Week33  1.332105
# Week34  0.498753

# %%
#가중합 열삭제
#vendor_weigh_2_1 = vendor_weigh_2_1.drop(['Weight_sum'])

# %%
#[ 삼성 = 0A709A, 샤오미 = #F44E54, 리얼미 = #76AD3B,  오렌지 = #FF9904,  노랑 = #FDDB5E, #BAF1A1 =연두
# [ 초록 = #76AD3B, skyblue, #F44E54= 연한 레드계열


# 누적막대그래프 만들기
vendor_weigh_2_per.plot.bar(stacked=True, fontsize=25,
                          colors =['#FF9904', '#F44E54','#FDDB5E', '#BAF1A1', '#76AD3B','dodgerblue','green'], alpha = 0.7)

# Set the title and labels

plt.rcParams['figure.figsize'] = [15, 13]
plt.legend(fontsize = 22, loc='lower right')
plt.xlabel('weeks', fontsize=23)
plt.ylabel('Percentage', fontsize=23)
plt.title('Flipkart Weekly Review Share', fontsize=40)


# show the plot
plt.show()
# Out:
# C:\Users\LES\AppData\Roaming\Python\Python37\site-packages\pandas\plotting\_core.py:185: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   warnings.warn(("'colors' is being deprecated. Please use 'color'"

# %%
x= vendor_weigh_review_count.columns[0:]
y=  vendor_weigh_review_count[0:]

pal = ['#FF9904', '#F44E54','#FDDB5E', '#BAF1A1', '#76AD3B','dodgerblue','green']
plt.stackplot(x,y, labels=['Realme', 'Xiaomi', 'Vivo','Others', 'Huawei', 'Samsung', 'OPPO'], 
              colors=pal, alpha=0.7 )

plt.title("Flipkart Weekly Review Count", fontsize=40, fontweight=0, color='black')
plt.xlabel("Weeks", fontsize = 24)
plt.xticks(fontsize = 24)

plt.ylabel("Review counts", fontsize = 24)
plt.yticks(fontsize = 24)

plt.legend(loc='upper left', fontsize = 22)
plt.show()
